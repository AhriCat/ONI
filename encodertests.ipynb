# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, embed_dim, num_heads):
        super(MultiHeadSelfAttention, self).__init__()
        self.num_heads = num_heads
        self.embed_dim = embed_dim

        assert embed_dim % num_heads == 0, "embed_dim must be divisible by num_heads"
        self.depth = embed_dim // num_heads

        self.wq = nn.Linear(embed_dim, embed_dim)
        self.wk = nn.Linear(embed_dim, embed_dim)
        self.wv = nn.Linear(embed_dim, embed_dim)
        self.dense = nn.Linear(embed_dim, embed_dim)
        self.dropout = nn.Dropout(0.1)

    def split_heads(self, x, batch_size):
        x = x.view(batch_size, -1, self.num_heads, self.depth)
        return x.permute(0, 2, 1, 3)

    def forward(self, v, k, q, mask=None):
        batch_size = q.size(0)

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        matmul_qk = torch.matmul(q, k.transpose(-2, -1))
        depth = k.size(-1)
        logits = matmul_qk / torch.sqrt(torch.tensor(depth, dtype=torch.float32))

        if mask is not None:
            logits += (mask * -1e9)

        attention_weights = F.softmax(logits, dim=-1)
        output = torch.matmul(attention_weights, v)
        output = output.permute(0, 2, 1, 3).contiguous()
        output = output.view(batch_size, -1, self.embed_dim)

        output = self.dropout(output)
        return self.dense(output)

class TransformerDoubleEncoder(nn.Module):
    def __init__(self, num_layers, d_model, num_heads, d_ff, input_vocab_size, output_vocab_size, max_seq_length):
        super(TransformerDoubleEncoder, self).__init__()

        self.input_embedding = nn.Embedding(input_vocab_size, d_model)
        self.attn = MultiHeadSelfAttention(num_layers, num_heads)
        self.output_embedding = nn.Embedding(output_vocab_size, d_model)
        self.attn2 = MultiHeadSelfAttention(d_model, num_heads)
        self.positional_encoding = nn.Parameter(torch.zeros(1, max_seq_length, d_model))
        
        self.encoder_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(d_model, num_heads, d_ff) for _ in range(num_layers)
        
        ])
        self.decoder_layers = nn.ModuleList([
            nn.TransformerDecoderLayer(d_model, num_heads, d_ff) for _ in range(num_layers)
        ])
        
        self.linear = nn.Linear(d_model, output_vocab_size)
        self.softmax = nn.Softmax(dim=-1)
        
    def forward(self, src, tgt):
        src = self.input_embedding(src) + self.positional_encoding[:, :src.size(1), :]
        atg = self.attn(self.input_embedding(src)+self.positional_encoding[:, :src.size(1), :])
        tgt = self.output_embedding(tgt) + self.positional_encoding[:, :tgt.size(1), :]
        
        for layer in self.encoder_layers:
            src = layer(src)
        
        for layer in self.encoder_layers:
            atg = layer(atg)
        
        for layer in self.decoder_layers:
            tgt = layer(tgt, src)
        
        output = self.linear(tgt)
        return self.softmax(output)

# Parámetros del modelo
num_layers = 64  # Número de capas
d_model = 2048  # Dimensionalidad de los embeddings
num_heads = 64  # Número de cabezas de atención
d_ff = 8192  # Dimensionalidad de la capa feed-forward
input_vocab_size = 600000  # Tamaño del vocabulario de entrada
output_vocab_size = 600000  # Tamaño del vocabulario de salida
max_seq_length = 256  # Longitud máxima de la secuencia

# Crear el modelo
model = TransformerDoubleEncoder(num_layers, d_model, num_heads, d_ff, input_vocab_size, output_vocab_size, max_seq_length)

# Contar el número de parámetros
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Number of parameters: {num_params}")

# %%
from torch import optim
import torch.nn as nn
import numpy as np
import torch
import torch.nn.functional as F

def ids_from_chars(text):
    vocab = list(set(''.join([char for sentence in corpus for char in sentence])))
    vocab.sort()
    vocab_to_id = {char: idx for idx, char in enumerate(vocab)}
    return [vocab_to_id[char] for char in text if char in vocab_to_id]

def text_from_ids(ids):
    vocab = list(set(''.join([char for sentence in corpus for char in sentence])))
    vocab.sort()
    id_to_vocab = {idx: char for idx, char in enumerate(vocab)}
    return ''.join([id_to_vocab[idx] for idx in ids if idx in id_to_vocab])

corpus = ['User: this is a test prompt.', 'Model: Oh, okay!']
# Define the train function
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train(corpus, epochs):
    for epoch in range(epochs):
        for input_example, target_example in dataset:
            input_example = torch.tensor(input_example).long()
            target_example = torch.tensor(target_example).long()
            optimizer.zero_grad()
            if len(input_example.shape) == 1:
                input_example = input_example.unsqueeze(0)
            if len(target_example.shape) == 1:
                target_example = target_example.unsqueeze(0)
            predictions = model(input_example, target_example)
            loss = criterion(predictions, target_example)
            loss.backward()
            optimizer.step()
        print(f'Epoch {epoch+1}, Loss: {loss.item()}')
# Define the chat function
def chat(input_text):
    input_ids = ids_from_chars(np.array([input_text]))
    input_ids = torch.tensor(input_ids).unsqueeze(0)
    predictions = model(input_ids)
    sampled_indices = torch.multinomial(torch.softmax(predictions, dim=-1), num_samples=1)
    sampled_indices = sampled_indices.squeeze(-1).numpy()
    output_text = text_from_ids(sampled_indices)
    return output_text

# Example usage
corpus = ['User: this is a test prompt.', 'Model: Oh, okay!']
vocab_size = len(set(corpus))
embedding_dim = 256
rnn_units = 1024
seq_length = 100


# Create a dataset from the corpus
dataset = [(ids_from_chars(np.array([input_text])), ids_from_chars(np.array([target_text]))) for input_text, target_text in zip(corpus, corpus[1:]+[''])]

train(corpus, epochs=20)

print(chat('User: this is a test prompt.'))

# Example usage

vocab_size = len(set(corpus))
embedding_dim = 256
rnn_units = 1024
seq_length = 100

train(corpus, epochs=20)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 59
#      56 # Create a dataset from the corpus
#      57 dataset = [(ids_from_chars(np.array([input_text])), ids_from_chars(np.array([target_text]))) for input_text, target_text in zip(corpus, corpus[1:]+[''])]
# ---> 59 train(corpus, epochs=20)
#      61 print(chat('User: this is a test prompt.'))
#      63 # Example usage
#
# Cell In[17], line 33, in train(corpus, epochs)
#      31 if len(target_example.shape) == 1:
#      32     target_example = target_example.unsqueeze(0)
# ---> 33 predictions = model(input_example, target_example)
#      34 loss = criterion(predictions, target_example)
#      35 loss.backward()
#
# File c:\Users\jonny\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jonny\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[1], line 72, in TransformerDoubleEncoder.forward(self, src, tgt)
#      70 def forward(self, src, tgt):
#      71     src = self.input_embedding(src) + self.positional_encoding[:, :src.size(1), :]
# ---> 72     atg = self.attn(self.input_embedding(src)+self.positional_encoding[:, :src.size(1), :])
#      73     tgt = self.output_embedding(tgt) + self.positional_encoding[:, :tgt.size(1), :]
#      75     for layer in self.encoder_layers:
#
# File c:\Users\jonny\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jonny\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\jonny\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\sparse.py:163, in Embedding.forward(self, input)
#     162 def forward(self, input: Tensor) -> Tensor:
# --> 163     return F.embedding(
#     164         input, self.weight, self.padding_idx, self.max_norm,
#     165         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File c:\Users\jonny\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:2264, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2258     # Note [embedding_renorm set_grad_enabled]
#    2259     # XXX: equivalent to
#    2260     # with torch.no_grad():
#    2261     #   torch.embedding_renorm_
#    2262     # remove once script supports set_grad_enabled
#    2263     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2264 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected tensor for argument #1 'indices' to have one of the following scalar types: Long, Int; but got torch.FloatTensor instead (while checking arguments for embedding)

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# TransformerDoubleEncoder                                     524,288
# ├─Embedding: 1-1                                             1,228,800,000
# ├─MultiHeadSelfAttention: 1-2                                --
# │    └─Linear: 2-1                                           4,160
# │    └─Linear: 2-2                                           4,160
# │    └─Linear: 2-3                                           4,160
# │    └─Linear: 2-4                                           4,160
# │    └─Dropout: 2-5                                          --
# ├─Embedding: 1-3                                             1,228,800,000
# ├─MultiHeadSelfAttention: 1-4                                --
# │    └─Linear: 2-6                                           4,196,352
# │    └─Linear: 2-7                                           4,196,352
# │    └─Linear: 2-8                                           4,196,352
# │    └─Linear: 2-9                                           4,196,352
# │    └─Dropout: 2-10                                         --
# ├─ModuleList: 1-5                                            --
# │    └─TransformerEncoderLayer: 2-11                         --
# │    │    └─MultiheadAttention: 3-1                          16,785,408
# │    │    └─Linear: 3-2                                      16,785,408
# │    │    └─Dropout: 3-3                                     --
# │    │    └─Linear: 3-4                                      16,779,264
# │    │    └─LayerNorm: 3-5                                   4,096
# │    │    └─LayerNorm: 3-6                                   4,096
# │    │    └─Dropout: 3-7                                     --
# │    │    └─Dropout: 3-8                                     --
# │    └─TransformerEncoderLayer: 2-12                         --
# │    │    └─MultiheadAttention: 3-9                          16,785,408
# │    │    └─Linear: 3-10                                     16,785,408
# │    │    └─Dropout: 3-11                                    --
# │    │    └─Linear: 3-12                                     16,779,264
# │    │    └─LayerNorm: 3-13                                  4,096
# │    │    └─LayerNorm: 3-14                                  4,096
# │    │    └─Dropout: 3-15                                    --
# │    │    └─Dropout: 3-16                                    --
# │    └─TransformerEncoderLayer: 2-13                         --
# │    │    └─MultiheadAttention: 3-17                         16,785,408
# │    │    └─Linear: 3-18                                     16,785,408
# │    │    └─Dropout: 3-19                                    --
# │    │    └─Linear: 3-20                                     16,779,264
# │    │    └─LayerNorm: 3-21                                  4,096
# │    │    └─LayerNorm: 3-22                                  4,096
# │    │    └─Dropout: 3-23                                    --
# │    │    └─Dropout: 3-24                                    --
# │    └─TransformerEncoderLayer: 2-14                         --
# │    │    └─MultiheadAttention: 3-25                         16,785,408
# │    │    └─Linear: 3-26                                     16,785,408
# │    │    └─Dropout: 3-27                                    --
# │    │    └─Linear: 3-28                                     16,779,264
# │    │    └─LayerNorm: 3-29                                  4,096
# │    │    └─LayerNorm: 3-30                                  4,096
# │    │    └─Dropout: 3-31                                    --
# │    │    └─Dropout: 3-32                                    --
# │    └─TransformerEncoderLayer: 2-15                         --
# │    │    └─MultiheadAttention: 3-33                         16,785,408
# │    │    └─Linear: 3-34                                     16,785,408
# │    │    └─Dropout: 3-35                                    --
# │    │    └─Linear: 3-36                                     16,779,264
# │    │    └─LayerNorm: 3-37                                  4,096
# │    │    └─LayerNorm: 3-38                                  4,096
# │    │    └─Dropout: 3-39                                    --
# │    │    └─Dropout: 3-40                                    --
# │    └─TransformerEncoderLayer: 2-16                         --
# │    │    └─MultiheadAttention: 3-41                         16,785,408
# │    │    └─Linear: 3-42                                     16,785,408
# │    │    └─Dropout: 3-43                                    --
# │    │    └─Linear: 3-44                                     16,779,264
# │    │    └─LayerNorm: 3-45                                  4,096
# │    │    └─LayerNorm: 3-46                                  4,096
# │    │    └─Dropout: 3-47                                    --
# │    │    └─Dropout: 3-48                                    --
# │    └─TransformerEncoderLayer: 2-17                         --
# │    │    └─MultiheadAttention: 3-49                         16,785,408
# │    │    └─Linear: 3-50                                     16,785,408
# │    │    └─Dropout: 3-51                                    --
# │    │    └─Linear: 3-52                                     16,779,264
# │    │    └─LayerNorm: 3-53                                  4,096
# │    │    └─LayerNorm: 3-54                                  4,096
# │    │    └─Dropout: 3-55                                    --
# │    │    └─Dropout: 3-56                                    --
# │    └─TransformerEncoderLayer: 2-18                         --
# │    │    └─MultiheadAttention: 3-57                         16,785,408
# │    │    └─Linear: 3-58                                     16,785,408
# │    │    └─Dropout: 3-59                                    --
# │    │    └─Linear: 3-60                                     16,779,264
# │    │    └─LayerNorm: 3-61                                  4,096
# │    │    └─LayerNorm: 3-62                                  4,096
# │    │    └─Dropout: 3-63                                    --
# │    │    └─Dropout: 3-64                                    --
# │    └─TransformerEncoderLayer: 2-19                         --
# │    │    └─MultiheadAttention: 3-65                         16,785,408
# │    │    └─Linear: 3-66                                     16,785,408
# │    │    └─Dropout: 3-67                                    --
# │    │    └─Linear: 3-68                                     16,779,264
# │    │    └─LayerNorm: 3-69                                  4,096
# │    │    └─LayerNorm: 3-70                                  4,096
# │    │    └─Dropout: 3-71                                    --
# │    │    └─Dropout: 3-72                                    --
# │    └─TransformerEncoderLayer: 2-20                         --
# │    │    └─MultiheadAttention: 3-73                         16,785,408
# │    │    └─Linear: 3-74                                     16,785,408
# │    │    └─Dropout: 3-75                                    --
# │    │    └─Linear: 3-76                                     16,779,264
# │    │    └─LayerNorm: 3-77                                  4,096
# │    │    └─LayerNorm: 3-78                                  4,096
# │    │    └─Dropout: 3-79                                    --
# │    │    └─Dropout: 3-80                                    --
# │    └─TransformerEncoderLayer: 2-21                         --
# │    │    └─MultiheadAttention: 3-81                         16,785,408
# │    │    └─Linear: 3-82                                     16,785,408
# │    │    └─Dropout: 3-83                                    --
# │    │    └─Linear: 3-84                                     16,779,264
# │    │    └─LayerNorm: 3-85                                  4,096
# │    │    └─LayerNorm: 3-86                                  4,096
# │    │    └─Dropout: 3-87                                    --
# │    │    └─Dropout: 3-88                                    --
# │    └─TransformerEncoderLayer: 2-22                         --
# │    │    └─MultiheadAttention: 3-89                         16,785,408
# │    │    └─Linear: 3-90                                     16,785,408
# │    │    └─Dropout: 3-91                                    --
# │    │    └─Linear: 3-92                                     16,779,264
# │    │    └─LayerNorm: 3-93                                  4,096
# │    │    └─LayerNorm: 3-94                                  4,096
# │    │    └─Dropout: 3-95                                    --
# │    │    └─Dropout: 3-96                                    --
# │    └─TransformerEncoderLayer: 2-23                         --
# │    │    └─MultiheadAttention: 3-97                         16,785,408
# │    │    └─Linear: 3-98                                     16,785,408
# │    │    └─Dropout: 3-99                                    --
# │    │    └─Linear: 3-100                                    16,779,264
# │    │    └─LayerNorm: 3-101                                 4,096
# │    │    └─LayerNorm: 3-102                                 4,096
# │    │    └─Dropout: 3-103                                   --
# │    │    └─Dropout: 3-104                                   --
# │    └─TransformerEncoderLayer: 2-24                         --
# │    │    └─MultiheadAttention: 3-105                        16,785,408
# │    │    └─Linear: 3-106                                    16,785,408
# │    │    └─Dropout: 3-107                                   --
# │    │    └─Linear: 3-108                                    16,779,264
# │    │    └─LayerNorm: 3-109                                 4,096
# │    │    └─LayerNorm: 3-110                                 4,096
# │    │    └─Dropout: 3-111                                   --
# │    │    └─Dropout: 3-112                                   --
# │    └─TransformerEncoderLayer: 2-25                         --
# │    │    └─MultiheadAttention: 3-113                        16,785,408
# │    │    └─Linear: 3-114                                    16,785,408
# │    │    └─Dropout: 3-115                                   --
# │    │    └─Linear: 3-116                                    16,779,264
# │    │    └─LayerNorm: 3-117                                 4,096
# │    │    └─LayerNorm: 3-118                                 4,096
# │    │    └─Dropout: 3-119                                   --
# │    │    └─Dropout: 3-120                                   --
# │    └─TransformerEncoderLayer: 2-26                         --
# │    │    └─MultiheadAttention: 3-121                        16,785,408
# │    │    └─Linear: 3-122                                    16,785,408
# │    │    └─Dropout: 3-123                                   --
# │    │    └─Linear: 3-124                                    16,779,264
# │    │    └─LayerNorm: 3-125                                 4,096
# │    │    └─LayerNorm: 3-126                                 4,096
# │    │    └─Dropout: 3-127                                   --
# │    │    └─Dropout: 3-128                                   --
# │    └─TransformerEncoderLayer: 2-27                         --
# │    │    └─MultiheadAttention: 3-129                        16,785,408
# │    │    └─Linear: 3-130                                    16,785,408
# │    │    └─Dropout: 3-131                                   --
# │    │    └─Linear: 3-132                                    16,779,264
# │    │    └─LayerNorm: 3-133                                 4,096
# │    │    └─LayerNorm: 3-134                                 4,096
# │    │    └─Dropout: 3-135                                   --
# │    │    └─Dropout: 3-136                                   --
# │    └─TransformerEncoderLayer: 2-28                         --
# │    │    └─MultiheadAttention: 3-137                        16,785,408
# │    │    └─Linear: 3-138                                    16,785,408
# │    │    └─Dropout: 3-139                                   --
# │    │    └─Linear: 3-140                                    16,779,264
# │    │    └─LayerNorm: 3-141                                 4,096
# │    │    └─LayerNorm: 3-142                                 4,096
# │    │    └─Dropout: 3-143                                   --
# │    │    └─Dropout: 3-144                                   --
# │    └─TransformerEncoderLayer: 2-29                         --
# │    │    └─MultiheadAttention: 3-145                        16,785,408
# │    │    └─Linear: 3-146                                    16,785,408
# │    │    └─Dropout: 3-147                                   --
# │    │    └─Linear: 3-148                                    16,779,264
# │    │    └─LayerNorm: 3-149                                 4,096
# │    │    └─LayerNorm: 3-150                                 4,096
# │    │    └─Dropout: 3-151                                   --
# │    │    └─Dropout: 3-152                                   --
# │    └─TransformerEncoderLayer: 2-30                         --
# │    │    └─MultiheadAttention: 3-153                        16,785,408
# │    │    └─Linear: 3-154                                    16,785,408
# │    │    └─Dropout: 3-155                                   --
# │    │    └─Linear: 3-156                                    16,779,264
# │    │    └─LayerNorm: 3-157                                 4,096
# │    │    └─LayerNorm: 3-158                                 4,096
# │    │    └─Dropout: 3-159                                   --
# │    │    └─Dropout: 3-160                                   --
# │    └─TransformerEncoderLayer: 2-31                         --
# │    │    └─MultiheadAttention: 3-161                        16,785,408
# │    │    └─Linear: 3-162                                    16,785,408
# │    │    └─Dropout: 3-163                                   --
# │    │    └─Linear: 3-164                                    16,779,264
# │    │    └─LayerNorm: 3-165                                 4,096
# │    │    └─LayerNorm: 3-166                                 4,096
# │    │    └─Dropout: 3-167                                   --
# │    │    └─Dropout: 3-168                                   --
# │    └─TransformerEncoderLayer: 2-32                         --
# │    │    └─MultiheadAttention: 3-169                        16,785,408
# │    │    └─Linear: 3-170                                    16,785,408
# │    │    └─Dropout: 3-171                                   --
# │    │    └─Linear: 3-172                                    16,779,264
# │    │    └─LayerNorm: 3-173                                 4,096
# │    │    └─LayerNorm: 3-174                                 4,096
# │    │    └─Dropout: 3-175                                   --
# │    │    └─Dropout: 3-176                                   --
# │    └─TransformerEncoderLayer: 2-33                         --
# │    │    └─MultiheadAttention: 3-177                        16,785,408
# │    │    └─Linear: 3-178                                    16,785,408
# │    │    └─Dropout: 3-179                                   --
# │    │    └─Linear: 3-180                                    16,779,264
# │    │    └─LayerNorm: 3-181                                 4,096
# │    │    └─LayerNorm: 3-182                                 4,096
# │    │    └─Dropout: 3-183                                   --
# │    │    └─Dropout: 3-184                                   --
# │    └─TransformerEncoderLayer: 2-34                         --
# │    │    └─MultiheadAttention: 3-185                        16,785,408
# │    │    └─Linear: 3-186                                    16,785,408
# │    │    └─Dropout: 3-187                                   --
# │    │    └─Linear: 3-188                                    16,779,264
# │    │    └─LayerNorm: 3-189                                 4,096
# │    │    └─LayerNorm: 3-190                                 4,096
# │    │    └─Dropout: 3-191                                   --
# │    │    └─Dropout: 3-192                                   --
# │    └─TransformerEncoderLayer: 2-35                         --
# │    │    └─MultiheadAttention: 3-193                        16,785,408
# │    │    └─Linear: 3-194                                    16,785,408
# │    │    └─Dropout: 3-195                                   --
# │    │    └─Linear: 3-196                                    16,779,264
# │    │    └─LayerNorm: 3-197                                 4,096
# │    │    └─LayerNorm: 3-198                                 4,096
# │    │    └─Dropout: 3-199                                   --
# │    │    └─Dropout: 3-200                                   --
# │    └─TransformerEncoderLayer: 2-36                         --
# │    │    └─MultiheadAttention: 3-201                        16,785,408
# │    │    └─Linear: 3-202                                    16,785,408
# │    │    └─Dropout: 3-203                                   --
# │    │    └─Linear: 3-204                                    16,779,264
# │    │    └─LayerNorm: 3-205                                 4,096
# │    │    └─LayerNorm: 3-206                                 4,096
# │    │    └─Dropout: 3-207                                   --
# │    │    └─Dropout: 3-208                                   --
# │    └─TransformerEncoderLayer: 2-37                         --
# │    │    └─MultiheadAttention: 3-209                        16,785,408
# │    │    └─Linear: 3-210                                    16,785,408
# │    │    └─Dropout: 3-211                                   --
# │    │    └─Linear: 3-212                                    16,779,264
# │    │    └─LayerNorm: 3-213                                 4,096
# │    │    └─LayerNorm: 3-214                                 4,096
# │    │    └─Dropout: 3-215                                   --
# │    │    └─Dropout: 3-216                                   --
# │    └─TransformerEncoderLayer: 2-38                         --
# │    │    └─MultiheadAttention: 3-217                        16,785,408
# │    │    └─Linear: 3-218                                    16,785,408
# │    │    └─Dropout: 3-219                                   --
# │    │    └─Linear: 3-220                                    16,779,264
# │    │    └─LayerNorm: 3-221                                 4,096
# │    │    └─LayerNorm: 3-222                                 4,096
# │    │    └─Dropout: 3-223                                   --
# │    │    └─Dropout: 3-224                                   --
# │    └─TransformerEncoderLayer: 2-39                         --
# │    │    └─MultiheadAttention: 3-225                        16,785,408
# │    │    └─Linear: 3-226                                    16,785,408
# │    │    └─Dropout: 3-227                                   --
# │    │    └─Linear: 3-228                                    16,779,264
# │    │    └─LayerNorm: 3-229                                 4,096
# │    │    └─LayerNorm: 3-230                                 4,096
# │    │    └─Dropout: 3-231                                   --
# │    │    └─Dropout: 3-232                                   --
# │    └─TransformerEncoderLayer: 2-40                         --
# │    │    └─MultiheadAttention: 3-233                        16,785,408
# │    │    └─Linear: 3-234                                    16,785,408
# │    │    └─Dropout: 3-235                                   --
# │    │    └─Linear: 3-236                                    16,779,264
# │    │    └─LayerNorm: 3-237                                 4,096
# │    │    └─LayerNorm: 3-238                                 4,096
# │    │    └─Dropout: 3-239                                   --
# │    │    └─Dropout: 3-240                                   --
# │    └─TransformerEncoderLayer: 2-41                         --
# │    │    └─MultiheadAttention: 3-241                        16,785,408
# │    │    └─Linear: 3-242                                    16,785,408
# │    │    └─Dropout: 3-243                                   --
# │    │    └─Linear: 3-244                                    16,779,264
# │    │    └─LayerNorm: 3-245                                 4,096
# │    │    └─LayerNorm: 3-246                                 4,096
# │    │    └─Dropout: 3-247                                   --
# │    │    └─Dropout: 3-248                                   --
# │    └─TransformerEncoderLayer: 2-42                         --
# │    │    └─MultiheadAttention: 3-249                        16,785,408
# │    │    └─Linear: 3-250                                    16,785,408
# │    │    └─Dropout: 3-251                                   --
# │    │    └─Linear: 3-252                                    16,779,264
# │    │    └─LayerNorm: 3-253                                 4,096
# │    │    └─LayerNorm: 3-254                                 4,096
# │    │    └─Dropout: 3-255                                   --
# │    │    └─Dropout: 3-256                                   --
# │    └─TransformerEncoderLayer: 2-43                         --
# │    │    └─MultiheadAttention: 3-257                        16,785,408
# │    │    └─Linear: 3-258                                    16,785,408
# │    │    └─Dropout: 3-259                                   --
# │    │    └─Linear: 3-260                                    16,779,264
# │    │    └─LayerNorm: 3-261                                 4,096
# │    │    └─LayerNorm: 3-262                                 4,096
# │    │    └─Dropout: 3-263                                   --
# │    │    └─Dropout: 3-264                                   --
# │    └─TransformerEncoderLayer: 2-44                         --
# │    │    └─MultiheadAttention: 3-265                        16,785,408
# │    │    └─Linear: 3-266                                    16,785,408
# │    │    └─Dropout: 3-267                                   --
# │    │    └─Linear: 3-268                                    16,779,264
# │    │    └─LayerNorm: 3-269                                 4,096
# │    │    └─LayerNorm: 3-270                                 4,096
# │    │    └─Dropout: 3-271                                   --
# │    │    └─Dropout: 3-272                                   --
# │    └─TransformerEncoderLayer: 2-45                         --
# │    │    └─MultiheadAttention: 3-273                        16,785,408
# │    │    └─Linear: 3-274                                    16,785,408
# │    │    └─Dropout: 3-275                                   --
# │    │    └─Linear: 3-276                                    16,779,264
# │    │    └─LayerNorm: 3-277                                 4,096
# │    │    └─LayerNorm: 3-278                                 4,096
# │    │    └─Dropout: 3-279                                   --
# │    │    └─Dropout: 3-280                                   --
# │    └─TransformerEncoderLayer: 2-46                         --
# │    │    └─MultiheadAttention: 3-281                        16,785,408
# │    │    └─Linear: 3-282                                    16,785,408
# │    │    └─Dropout: 3-283                                   --
# │    │    └─Linear: 3-284                                    16,779,264
# │    │    └─LayerNorm: 3-285                                 4,096
# │    │    └─LayerNorm: 3-286                                 4,096
# │    │    └─Dropout: 3-287                                   --
# │    │    └─Dropout: 3-288                                   --
# │    └─TransformerEncoderLayer: 2-47                         --
# │    │    └─MultiheadAttention: 3-289                        16,785,408
# │    │    └─Linear: 3-290                                    16,785,408
# │    │    └─Dropout: 3-291                                   --
# │    │    └─Linear: 3-292                                    16,779,264
# │    │    └─LayerNorm: 3-293                                 4,096
# │    │    └─LayerNorm: 3-294                                 4,096
# │    │    └─Dropout: 3-295                                   --
# │    │    └─Dropout: 3-296                                   --
# │    └─TransformerEncoderLayer: 2-48                         --
# │    │    └─MultiheadAttention: 3-297                        16,785,408
# │    │    └─Linear: 3-298                                    16,785,408
# │    │    └─Dropout: 3-299                                   --
# │    │    └─Linear: 3-300                                    16,779,264
# │    │    └─LayerNorm: 3-301                                 4,096
# │    │    └─LayerNorm: 3-302                                 4,096
# │    │    └─Dropout: 3-303                                   --
# │    │    └─Dropout: 3-304                                   --
# │    └─TransformerEncoderLayer: 2-49                         --
# │    │    └─MultiheadAttention: 3-305                        16,785,408
# │    │    └─Linear: 3-306                                    16,785,408
# │    │    └─Dropout: 3-307                                   --
# │    │    └─Linear: 3-308                                    16,779,264
# │    │    └─LayerNorm: 3-309                                 4,096
# │    │    └─LayerNorm: 3-310                                 4,096
# │    │    └─Dropout: 3-311                                   --
# │    │    └─Dropout: 3-312                                   --
# │    └─TransformerEncoderLayer: 2-50                         --
# │    │    └─MultiheadAttention: 3-313                        16,785,408
# │    │    └─Linear: 3-314                                    16,785,408
# │    │    └─Dropout: 3-315                                   --
# │    │    └─Linear: 3-316                                    16,779,264
# │    │    └─LayerNorm: 3-317                                 4,096
# │    │    └─LayerNorm: 3-318                                 4,096
# │    │    └─Dropout: 3-319                                   --
# │    │    └─Dropout: 3-320                                   --
# │    └─TransformerEncoderLayer: 2-51                         --
# │    │    └─MultiheadAttention: 3-321                        16,785,408
# │    │    └─Linear: 3-322                                    16,785,408
# │    │    └─Dropout: 3-323                                   --
# │    │    └─Linear: 3-324                                    16,779,264
# │    │    └─LayerNorm: 3-325                                 4,096
# │    │    └─LayerNorm: 3-326                                 4,096
# │    │    └─Dropout: 3-327                                   --
# │    │    └─Dropout: 3-328                                   --
# │    └─TransformerEncoderLayer: 2-52                         --
# │    │    └─MultiheadAttention: 3-329                        16,785,408
# │    │    └─Linear: 3-330                                    16,785,408
# │    │    └─Dropout: 3-331                                   --
# │    │    └─Linear: 3-332                                    16,779,264
# │    │    └─LayerNorm: 3-333                                 4,096
# │    │    └─LayerNorm: 3-334                                 4,096
# │    │    └─Dropout: 3-335                                   --
# │    │    └─Dropout: 3-336                                   --
# │    └─TransformerEncoderLayer: 2-53                         --
# │    │    └─MultiheadAttention: 3-337                        16,785,408
# │    │    └─Linear: 3-338                                    16,785,408
# │    │    └─Dropout: 3-339                                   --
# │    │    └─Linear: 3-340                                    16,779,264
# │    │    └─LayerNorm: 3-341                                 4,096
# │    │    └─LayerNorm: 3-342                                 4,096
# │    │    └─Dropout: 3-343                                   --
# │    │    └─Dropout: 3-344                                   --
# │    └─TransformerEncoderLayer: 2-54                         --
# │    │    └─MultiheadAttention: 3-345                        16,785,408
# │    │    └─Linear: 3-346                                    16,785,408
# │    │    └─Dropout: 3-347                                   --
# │    │    └─Linear: 3-348                                    16,779,264
# │    │    └─LayerNorm: 3-349                                 4,096
# │    │    └─LayerNorm: 3-350                                 4,096
# │    │    └─Dropout: 3-351                                   --
# │    │    └─Dropout: 3-352                                   --
# │    └─TransformerEncoderLayer: 2-55                         --
# │    │    └─MultiheadAttention: 3-353                        16,785,408
# │    │    └─Linear: 3-354                                    16,785,408
# │    │    └─Dropout: 3-355                                   --
# │    │    └─Linear: 3-356                                    16,779,264
# │    │    └─LayerNorm: 3-357                                 4,096
# │    │    └─LayerNorm: 3-358                                 4,096
# │    │    └─Dropout: 3-359                                   --
# │    │    └─Dropout: 3-360                                   --
# │    └─TransformerEncoderLayer: 2-56                         --
# │    │    └─MultiheadAttention: 3-361                        16,785,408
# │    │    └─Linear: 3-362                                    16,785,408
# │    │    └─Dropout: 3-363                                   --
# │    │    └─Linear: 3-364                                    16,779,264
# │    │    └─LayerNorm: 3-365                                 4,096
# │    │    └─LayerNorm: 3-366                                 4,096
# │    │    └─Dropout: 3-367                                   --
# │    │    └─Dropout: 3-368                                   --
# │    └─TransformerEncoderLayer: 2-57                         --
# │    │    └─MultiheadAttention: 3-369                        16,785,408
# │    │    └─Linear: 3-370                                    16,785,408
# │    │    └─Dropout: 3-371                                   --
# │    │    └─Linear: 3-372                                    16,779,264
# │    │    └─LayerNorm: 3-373                                 4,096
# │    │    └─LayerNorm: 3-374                                 4,096
# │    │    └─Dropout: 3-375                                   --
# │    │    └─Dropout: 3-376                                   --
# │    └─TransformerEncoderLayer: 2-58                         --
# │    │    └─MultiheadAttention: 3-377                        16,785,408
# │    │    └─Linear: 3-378                                    16,785,408
# │    │    └─Dropout: 3-379                                   --
# │    │    └─Linear: 3-380                                    16,779,264
# │    │    └─LayerNorm: 3-381                                 4,096
# │    │    └─LayerNorm: 3-382                                 4,096
# │    │    └─Dropout: 3-383                                   --
# │    │    └─Dropout: 3-384                                   --
# │    └─TransformerEncoderLayer: 2-59                         --
# │    │    └─MultiheadAttention: 3-385                        16,785,408
# │    │    └─Linear: 3-386                                    16,785,408
# │    │    └─Dropout: 3-387                                   --
# │    │    └─Linear: 3-388                                    16,779,264
# │    │    └─LayerNorm: 3-389                                 4,096
# │    │    └─LayerNorm: 3-390                                 4,096
# │    │    └─Dropout: 3-391                                   --
# │    │    └─Dropout: 3-392                                   --
# │    └─TransformerEncoderLayer: 2-60                         --
# │    │    └─MultiheadAttention: 3-393                        16,785,408
# │    │    └─Linear: 3-394                                    16,785,408
# │    │    └─Dropout: 3-395                                   --
# │    │    └─Linear: 3-396                                    16,779,264
# │    │    └─LayerNorm: 3-397                                 4,096
# │    │    └─LayerNorm: 3-398                                 4,096
# │    │    └─Dropout: 3-399                                   --
# │    │    └─Dropout: 3-400                                   --
# │    └─TransformerEncoderLayer: 2-61                         --
# │    │    └─MultiheadAttention: 3-401                        16,785,408
# │    │    └─Linear: 3-402                                    16,785,408
# │    │    └─Dropout: 3-403                                   --
# │    │    └─Linear: 3-404                                    16,779,264
# │    │    └─LayerNorm: 3-405                                 4,096
# │    │    └─LayerNorm: 3-406                                 4,096
# │    │    └─Dropout: 3-407                                   --
# │    │    └─Dropout: 3-408                                   --
# │    └─TransformerEncoderLayer: 2-62                         --
# │    │    └─MultiheadAttention: 3-409                        16,785,408
# │    │    └─Linear: 3-410                                    16,785,408
# │    │    └─Dropout: 3-411                                   --
# │    │    └─Linear: 3-412                                    16,779,264
# │    │    └─LayerNorm: 3-413                                 4,096
# │    │    └─LayerNorm: 3-414                                 4,096
# │    │    └─Dropout: 3-415                                   --
# │    │    └─Dropout: 3-416                                   --
# │    └─TransformerEncoderLayer: 2-63                         --
# │    │    └─MultiheadAttention: 3-417                        16,785,408
# │    │    └─Linear: 3-418                                    16,785,408
# │    │    └─Dropout: 3-419                                   --
# │    │    └─Linear: 3-420                                    16,779,264
# │    │    └─LayerNorm: 3-421                                 4,096
# │    │    └─LayerNorm: 3-422                                 4,096
# │    │    └─Dropout: 3-423                                   --
# │    │    └─Dropout: 3-424                                   --
# │    └─TransformerEncoderLayer: 2-64                         --
# │    │    └─MultiheadAttention: 3-425                        16,785,408
# │    │    └─Linear: 3-426                                    16,785,408
# │    │    └─Dropout: 3-427                                   --
# │    │    └─Linear: 3-428                                    16,779,264
# │    │    └─LayerNorm: 3-429                                 4,096
# │    │    └─LayerNorm: 3-430                                 4,096
# │    │    └─Dropout: 3-431                                   --
# │    │    └─Dropout: 3-432                                   --
# │    └─TransformerEncoderLayer: 2-65                         --
# │    │    └─MultiheadAttention: 3-433                        16,785,408
# │    │    └─Linear: 3-434                                    16,785,408
# │    │    └─Dropout: 3-435                                   --
# │    │    └─Linear: 3-436                                    16,779,264
# │    │    └─LayerNorm: 3-437                                 4,096
# │    │    └─LayerNorm: 3-438                                 4,096
# │    │    └─Dropout: 3-439                                   --
# │    │    └─Dropout: 3-440                                   --
# │    └─TransformerEncoderLayer: 2-66                         --
# │    │    └─MultiheadAttention: 3-441                        16,785,408
# │    │    └─Linear: 3-442                                    16,785,408
# │    │    └─Dropout: 3-443                                   --
# │    │    └─Linear: 3-444                                    16,779,264
# │    │    └─LayerNorm: 3-445                                 4,096
# │    │    └─LayerNorm: 3-446                                 4,096
# │    │    └─Dropout: 3-447                                   --
# │    │    └─Dropout: 3-448                                   --
# │    └─TransformerEncoderLayer: 2-67                         --
# │    │    └─MultiheadAttention: 3-449                        16,785,408
# │    │    └─Linear: 3-450                                    16,785,408
# │    │    └─Dropout: 3-451                                   --
# │    │    └─Linear: 3-452                                    16,779,264
# │    │    └─LayerNorm: 3-453                                 4,096
# │    │    └─LayerNorm: 3-454                                 4,096
# │    │    └─Dropout: 3-455                                   --
# │    │    └─Dropout: 3-456                                   --
# │    └─TransformerEncoderLayer: 2-68                         --
# │    │    └─MultiheadAttention: 3-457                        16,785,408
# │    │    └─Linear: 3-458                                    16,785,408
# │    │    └─Dropout: 3-459                                   --
# │    │    └─Linear: 3-460                                    16,779,264
# │    │    └─LayerNorm: 3-461                                 4,096
# │    │    └─LayerNorm: 3-462                                 4,096
# │    │    └─Dropout: 3-463                                   --
# │    │    └─Dropout: 3-464                                   --
# │    └─TransformerEncoderLayer: 2-69                         --
# │    │    └─MultiheadAttention: 3-465                        16,785,408
# │    │    └─Linear: 3-466                                    16,785,408
# │    │    └─Dropout: 3-467                                   --
# │    │    └─Linear: 3-468                                    16,779,264
# │    │    └─LayerNorm: 3-469                                 4,096
# │    │    └─LayerNorm: 3-470                                 4,096
# │    │    └─Dropout: 3-471                                   --
# │    │    └─Dropout: 3-472                                   --
# │    └─TransformerEncoderLayer: 2-70                         --
# │    │    └─MultiheadAttention: 3-473                        16,785,408
# │    │    └─Linear: 3-474                                    16,785,408
# │    │    └─Dropout: 3-475                                   --
# │    │    └─Linear: 3-476                                    16,779,264
# │    │    └─LayerNorm: 3-477                                 4,096
# │    │    └─LayerNorm: 3-478                                 4,096
# │    │    └─Dropout: 3-479                                   --
# │    │    └─Dropout: 3-480                                   --
# │    └─TransformerEncoderLayer: 2-71                         --
# │    │    └─MultiheadAttention: 3-481                        16,785,408
# │    │    └─Linear: 3-482                                    16,785,408
# │    │    └─Dropout: 3-483                                   --
# │    │    └─Linear: 3-484                                    16,779,264
# │    │    └─LayerNorm: 3-485                                 4,096
# │    │    └─LayerNorm: 3-486                                 4,096
# │    │    └─Dropout: 3-487                                   --
# │    │    └─Dropout: 3-488                                   --
# │    └─TransformerEncoderLayer: 2-72                         --
# │    │    └─MultiheadAttention: 3-489                        16,785,408
# │    │    └─Linear: 3-490                                    16,785,408
# │    │    └─Dropout: 3-491                                   --
# │    │    └─Linear: 3-492                                    16,779,264
# │    │    └─LayerNorm: 3-493                                 4,096
# │    │    └─LayerNorm: 3-494                                 4,096
# │    │    └─Dropout: 3-495                                   --
# │    │    └─Dropout: 3-496                                   --
# │    └─TransformerEncoderLayer: 2-73                         --
# │    │    └─MultiheadAttention: 3-497                        16,785,408
# │    │    └─Linear: 3-498                                    16,785,408
# │    │    └─Dropout: 3-499                                   --
# │    │    └─Linear: 3-500                                    16,779,264
# │    │    └─LayerNorm: 3-501                                 4,096
# │    │    └─LayerNorm: 3-502                                 4,096
# │    │    └─Dropout: 3-503                                   --
# │    │    └─Dropout: 3-504                                   --
# │    └─TransformerEncoderLayer: 2-74                         --
# │    │    └─MultiheadAttention: 3-505                        16,785,408
# │    │    └─Linear: 3-506                                    16,785,408
# │    │    └─Dropout: 3-507                                   --
# │    │    └─Linear: 3-508                                    16,779,264
# │    │    └─LayerNorm: 3-509                                 4,096
# │    │    └─LayerNorm: 3-510                                 4,096
# │    │    └─Dropout: 3-511                                   --
# │    │    └─Dropout: 3-512                                   --
# ├─ModuleList: 1-6                                            --
# │    └─TransformerDecoderLayer: 2-75                         --
# │    │    └─MultiheadAttention: 3-513                        16,785,408
# │    │    └─MultiheadAttention: 3-514                        16,785,408
# │    │    └─Linear: 3-515                                    16,785,408
# │    │    └─Dropout: 3-516                                   --
# │    │    └─Linear: 3-517                                    16,779,264
# │    │    └─LayerNorm: 3-518                                 4,096
# │    │    └─LayerNorm: 3-519                                 4,096
# │    │    └─LayerNorm: 3-520                                 4,096
# │    │    └─Dropout: 3-521                                   --
# │    │    └─Dropout: 3-522                                   --
# │    │    └─Dropout: 3-523                                   --
# │    └─TransformerDecoderLayer: 2-76                         --
# │    │    └─MultiheadAttention: 3-524                        16,785,408
# │    │    └─MultiheadAttention: 3-525                        16,785,408
# │    │    └─Linear: 3-526                                    16,785,408
# │    │    └─Dropout: 3-527                                   --
# │    │    └─Linear: 3-528                                    16,779,264
# │    │    └─LayerNorm: 3-529                                 4,096
# │    │    └─LayerNorm: 3-530                                 4,096
# │    │    └─LayerNorm: 3-531                                 4,096
# │    │    └─Dropout: 3-532                                   --
# │    │    └─Dropout: 3-533                                   --
# │    │    └─Dropout: 3-534                                   --
# │    └─TransformerDecoderLayer: 2-77                         --
# │    │    └─MultiheadAttention: 3-535                        16,785,408
# │    │    └─MultiheadAttention: 3-536                        16,785,408
# │    │    └─Linear: 3-537                                    16,785,408
# │    │    └─Dropout: 3-538                                   --
# │    │    └─Linear: 3-539                                    16,779,264
# │    │    └─LayerNorm: 3-540                                 4,096
# │    │    └─LayerNorm: 3-541                                 4,096
# │    │    └─LayerNorm: 3-542                                 4,096
# │    │    └─Dropout: 3-543                                   --
# │    │    └─Dropout: 3-544                                   --
# │    │    └─Dropout: 3-545                                   --
# │    └─TransformerDecoderLayer: 2-78                         --
# │    │    └─MultiheadAttention: 3-546                        16,785,408
# │    │    └─MultiheadAttention: 3-547                        16,785,408
# │    │    └─Linear: 3-548                                    16,785,408
# │    │    └─Dropout: 3-549                                   --
# │    │    └─Linear: 3-550                                    16,779,264
# │    │    └─LayerNorm: 3-551                                 4,096
# │    │    └─LayerNorm: 3-552                                 4,096
# │    │    └─LayerNorm: 3-553                                 4,096
# │    │    └─Dropout: 3-554                                   --
# │    │    └─Dropout: 3-555                                   --
# │    │    └─Dropout: 3-556                                   --
# │    └─TransformerDecoderLayer: 2-79                         --
# │    │    └─MultiheadAttention: 3-557                        16,785,408
# │    │    └─MultiheadAttention: 3-558                        16,785,408
# │    │    └─Linear: 3-559                                    16,785,408
# │    │    └─Dropout: 3-560                                   --
# │    │    └─Linear: 3-561                                    16,779,264
# │    │    └─LayerNorm: 3-562                                 4,096
# │    │    └─LayerNorm: 3-563                                 4,096
# │    │    └─LayerNorm: 3-564                                 4,096
# │    │    └─Dropout: 3-565                                   --
# │    │    └─Dropout: 3-566                                   --
# │    │    └─Dropout: 3-567                                   --
# │    └─TransformerDecoderLayer: 2-80                         --
# │    │    └─MultiheadAttention: 3-568                        16,785,408
# │    │    └─MultiheadAttention: 3-569                        16,785,408
# │    │    └─Linear: 3-570                                    16,785,408
# │    │    └─Dropout: 3-571                                   --
# │    │    └─Linear: 3-572                                    16,779,264
# │    │    └─LayerNorm: 3-573                                 4,096
# │    │    └─LayerNorm: 3-574                                 4,096
# │    │    └─LayerNorm: 3-575                                 4,096
# │    │    └─Dropout: 3-576                                   --
# │    │    └─Dropout: 3-577                                   --
# │    │    └─Dropout: 3-578                                   --
# │    └─TransformerDecoderLayer: 2-81                         --
# │    │    └─MultiheadAttention: 3-579                        16,785,408
# │    │    └─MultiheadAttention: 3-580                        16,785,408
# │    │    └─Linear: 3-581                                    16,785,408
# │    │    └─Dropout: 3-582                                   --
# │    │    └─Linear: 3-583                                    16,779,264
# │    │    └─LayerNorm: 3-584                                 4,096
# │    │    └─LayerNorm: 3-585                                 4,096
# │    │    └─LayerNorm: 3-586                                 4,096
# │    │    └─Dropout: 3-587                                   --
# │    │    └─Dropout: 3-588                                   --
# │    │    └─Dropout: 3-589                                   --
# │    └─TransformerDecoderLayer: 2-82                         --
# │    │    └─MultiheadAttention: 3-590                        16,785,408
# │    │    └─MultiheadAttention: 3-591                        16,785,408
# │    │    └─Linear: 3-592                                    16,785,408
# │    │    └─Dropout: 3-593                                   --
# │    │    └─Linear: 3-594                                    16,779,264
# │    │    └─LayerNorm: 3-595                                 4,096
# │    │    └─LayerNorm: 3-596                                 4,096
# │    │    └─LayerNorm: 3-597                                 4,096
# │    │    └─Dropout: 3-598                                   --
# │    │    └─Dropout: 3-599                                   --
# │    │    └─Dropout: 3-600                                   --
# │    └─TransformerDecoderLayer: 2-83                         --
# │    │    └─MultiheadAttention: 3-601                        16,785,408
# │    │    └─MultiheadAttention: 3-602                        16,785,408
# │    │    └─Linear: 3-603                                    16,785,408
# │    │    └─Dropout: 3-604                                   --
# │    │    └─Linear: 3-605                                    16,779,264
# │    │    └─LayerNorm: 3-606                                 4,096
# │    │    └─LayerNorm: 3-607                                 4,096
# │    │    └─LayerNorm: 3-608                                 4,096
# │    │    └─Dropout: 3-609                                   --
# │    │    └─Dropout: 3-610                                   --
# │    │    └─Dropout: 3-611                                   --
# │    └─TransformerDecoderLayer: 2-84                         --
# │    │    └─MultiheadAttention: 3-612                        16,785,408
# │    │    └─MultiheadAttention: 3-613                        16,785,408
# │    │    └─Linear: 3-614                                    16,785,408
# │    │    └─Dropout: 3-615                                   --
# │    │    └─Linear: 3-616                                    16,779,264
# │    │    └─LayerNorm: 3-617                                 4,096
# ...
# │    │    └─Dropout: 3-1005                                  --
# │    │    └─Dropout: 3-1006                                  --
# │    │    └─Dropout: 3-1007                                  --
# │    └─TransformerDecoderLayer: 2-120                        --
# │    │    └─MultiheadAttention: 3-1008                       16,785,408
# │    │    └─MultiheadAttention: 3-1009                       16,785,408
# │    │    └─Linear: 3-1010                                   16,785,408
# │    │    └─Dropout: 3-1011                                  --
# │    │    └─Linear: 3-1012                                   16,779,264
# │    │    └─LayerNorm: 3-1013                                4,096
# │    │    └─LayerNorm: 3-1014                                4,096
# │    │    └─LayerNorm: 3-1015                                4,096
# │    │    └─Dropout: 3-1016                                  --
# │    │    └─Dropout: 3-1017                                  --
# │    │    └─Dropout: 3-1018                                  --
# │    └─TransformerDecoderLayer: 2-121                        --
# │    │    └─MultiheadAttention: 3-1019                       16,785,408
# │    │    └─MultiheadAttention: 3-1020                       16,785,408
# │    │    └─Linear: 3-1021                                   16,785,408
# │    │    └─Dropout: 3-1022                                  --
# │    │    └─Linear: 3-1023                                   16,779,264
# │    │    └─LayerNorm: 3-1024                                4,096
# │    │    └─LayerNorm: 3-1025                                4,096
# │    │    └─LayerNorm: 3-1026                                4,096
# │    │    └─Dropout: 3-1027                                  --
# │    │    └─Dropout: 3-1028                                  --
# │    │    └─Dropout: 3-1029                                  --
# │    └─TransformerDecoderLayer: 2-122                        --
# │    │    └─MultiheadAttention: 3-1030                       16,785,408
# │    │    └─MultiheadAttention: 3-1031                       16,785,408
# │    │    └─Linear: 3-1032                                   16,785,408
# │    │    └─Dropout: 3-1033                                  --
# │    │    └─Linear: 3-1034                                   16,779,264
# │    │    └─LayerNorm: 3-1035                                4,096
# │    │    └─LayerNorm: 3-1036                                4,096
# │    │    └─LayerNorm: 3-1037                                4,096
# │    │    └─Dropout: 3-1038                                  --
# │    │    └─Dropout: 3-1039                                  --
# │    │    └─Dropout: 3-1040                                  --
# │    └─TransformerDecoderLayer: 2-123                        --
# │    │    └─MultiheadAttention: 3-1041                       16,785,408
# │    │    └─MultiheadAttention: 3-1042                       16,785,408
# │    │    └─Linear: 3-1043                                   16,785,408
# │    │    └─Dropout: 3-1044                                  --
# │    │    └─Linear: 3-1045                                   16,779,264
# │    │    └─LayerNorm: 3-1046                                4,096
# │    │    └─LayerNorm: 3-1047                                4,096
# │    │    └─LayerNorm: 3-1048                                4,096
# │    │    └─Dropout: 3-1049                                  --
# │    │    └─Dropout: 3-1050                                  --
# │    │    └─Dropout: 3-1051                                  --
# │    └─TransformerDecoderLayer: 2-124                        --
# │    │    └─MultiheadAttention: 3-1052                       16,785,408
# │    │    └─MultiheadAttention: 3-1053                       16,785,408
# │    │    └─Linear: 3-1054                                   16,785,408
# │    │    └─Dropout: 3-1055                                  --
# │    │    └─Linear: 3-1056                                   16,779,264
# │    │    └─LayerNorm: 3-1057                                4,096
# │    │    └─LayerNorm: 3-1058                                4,096
# │    │    └─LayerNorm: 3-1059                                4,096
# │    │    └─Dropout: 3-1060                                  --
# │    │    └─Dropout: 3-1061                                  --
# │    │    └─Dropout: 3-1062                                  --
# │    └─TransformerDecoderLayer: 2-125                        --
# │    │    └─MultiheadAttention: 3-1063                       16,785,408
# │    │    └─MultiheadAttention: 3-1064                       16,785,408
# │    │    └─Linear: 3-1065                                   16,785,408
# │    │    └─Dropout: 3-1066                                  --
# │    │    └─Linear: 3-1067                                   16,779,264
# │    │    └─LayerNorm: 3-1068                                4,096
# │    │    └─LayerNorm: 3-1069                                4,096
# │    │    └─LayerNorm: 3-1070                                4,096
# │    │    └─Dropout: 3-1071                                  --
# │    │    └─Dropout: 3-1072                                  --
# │    │    └─Dropout: 3-1073                                  --
# │    └─TransformerDecoderLayer: 2-126                        --
# │    │    └─MultiheadAttention: 3-1074                       16,785,408
# │    │    └─MultiheadAttention: 3-1075                       16,785,408
# │    │    └─Linear: 3-1076                                   16,785,408
# │    │    └─Dropout: 3-1077                                  --
# │    │    └─Linear: 3-1078                                   16,779,264
# │    │    └─LayerNorm: 3-1079                                4,096
# │    │    └─LayerNorm: 3-1080                                4,096
# │    │    └─LayerNorm: 3-1081                                4,096
# │    │    └─Dropout: 3-1082                                  --
# │    │    └─Dropout: 3-1083                                  --
# │    │    └─Dropout: 3-1084                                  --
# │    └─TransformerDecoderLayer: 2-127                        --
# │    │    └─MultiheadAttention: 3-1085                       16,785,408
# │    │    └─MultiheadAttention: 3-1086                       16,785,408
# │    │    └─Linear: 3-1087                                   16,785,408
# │    │    └─Dropout: 3-1088                                  --
# │    │    └─Linear: 3-1089                                   16,779,264
# │    │    └─LayerNorm: 3-1090                                4,096
# │    │    └─LayerNorm: 3-1091                                4,096
# │    │    └─LayerNorm: 3-1092                                4,096
# │    │    └─Dropout: 3-1093                                  --
# │    │    └─Dropout: 3-1094                                  --
# │    │    └─Dropout: 3-1095                                  --
# │    └─TransformerDecoderLayer: 2-128                        --
# │    │    └─MultiheadAttention: 3-1096                       16,785,408
# │    │    └─MultiheadAttention: 3-1097                       16,785,408
# │    │    └─Linear: 3-1098                                   16,785,408
# │    │    └─Dropout: 3-1099                                  --
# │    │    └─Linear: 3-1100                                   16,779,264
# │    │    └─LayerNorm: 3-1101                                4,096
# │    │    └─LayerNorm: 3-1102                                4,096
# │    │    └─LayerNorm: 3-1103                                4,096
# │    │    └─Dropout: 3-1104                                  --
# │    │    └─Dropout: 3-1105                                  --
# │    │    └─Dropout: 3-1106                                  --
# │    └─TransformerDecoderLayer: 2-129                        --
# │    │    └─MultiheadAttention: 3-1107                       16,785,408
# │    │    └─MultiheadAttention: 3-1108                       16,785,408
# │    │    └─Linear: 3-1109                                   16,785,408
# │    │    └─Dropout: 3-1110                                  --
# │    │    └─Linear: 3-1111                                   16,779,264
# │    │    └─LayerNorm: 3-1112                                4,096
# │    │    └─LayerNorm: 3-1113                                4,096
# │    │    └─LayerNorm: 3-1114                                4,096
# │    │    └─Dropout: 3-1115                                  --
# │    │    └─Dropout: 3-1116                                  --
# │    │    └─Dropout: 3-1117                                  --
# │    └─TransformerDecoderLayer: 2-130                        --
# │    │    └─MultiheadAttention: 3-1118                       16,785,408
# │    │    └─MultiheadAttention: 3-1119                       16,785,408
# │    │    └─Linear: 3-1120                                   16,785,408
# │    │    └─Dropout: 3-1121                                  --
# │    │    └─Linear: 3-1122                                   16,779,264
# │    │    └─LayerNorm: 3-1123                                4,096
# │    │    └─LayerNorm: 3-1124                                4,096
# │    │    └─LayerNorm: 3-1125                                4,096
# │    │    └─Dropout: 3-1126                                  --
# │    │    └─Dropout: 3-1127                                  --
# │    │    └─Dropout: 3-1128                                  --
# │    └─TransformerDecoderLayer: 2-131                        --
# │    │    └─MultiheadAttention: 3-1129                       16,785,408
# │    │    └─MultiheadAttention: 3-1130                       16,785,408
# │    │    └─Linear: 3-1131                                   16,785,408
# │    │    └─Dropout: 3-1132                                  --
# │    │    └─Linear: 3-1133                                   16,779,264
# │    │    └─LayerNorm: 3-1134                                4,096
# │    │    └─LayerNorm: 3-1135                                4,096
# │    │    └─LayerNorm: 3-1136                                4,096
# │    │    └─Dropout: 3-1137                                  --
# │    │    └─Dropout: 3-1138                                  --
# │    │    └─Dropout: 3-1139                                  --
# │    └─TransformerDecoderLayer: 2-132                        --
# │    │    └─MultiheadAttention: 3-1140                       16,785,408
# │    │    └─MultiheadAttention: 3-1141                       16,785,408
# │    │    └─Linear: 3-1142                                   16,785,408
# │    │    └─Dropout: 3-1143                                  --
# │    │    └─Linear: 3-1144                                   16,779,264
# │    │    └─LayerNorm: 3-1145                                4,096
# │    │    └─LayerNorm: 3-1146                                4,096
# │    │    └─LayerNorm: 3-1147                                4,096
# │    │    └─Dropout: 3-1148                                  --
# │    │    └─Dropout: 3-1149                                  --
# │    │    └─Dropout: 3-1150                                  --
# │    └─TransformerDecoderLayer: 2-133                        --
# │    │    └─MultiheadAttention: 3-1151                       16,785,408
# │    │    └─MultiheadAttention: 3-1152                       16,785,408
# │    │    └─Linear: 3-1153                                   16,785,408
# │    │    └─Dropout: 3-1154                                  --
# │    │    └─Linear: 3-1155                                   16,779,264
# │    │    └─LayerNorm: 3-1156                                4,096
# │    │    └─LayerNorm: 3-1157                                4,096
# │    │    └─LayerNorm: 3-1158                                4,096
# │    │    └─Dropout: 3-1159                                  --
# │    │    └─Dropout: 3-1160                                  --
# │    │    └─Dropout: 3-1161                                  --
# │    └─TransformerDecoderLayer: 2-134                        --
# │    │    └─MultiheadAttention: 3-1162                       16,785,408
# │    │    └─MultiheadAttention: 3-1163                       16,785,408
# │    │    └─Linear: 3-1164                                   16,785,408
# │    │    └─Dropout: 3-1165                                  --
# │    │    └─Linear: 3-1166                                   16,779,264
# │    │    └─LayerNorm: 3-1167                                4,096
# │    │    └─LayerNorm: 3-1168                                4,096
# │    │    └─LayerNorm: 3-1169                                4,096
# │    │    └─Dropout: 3-1170                                  --
# │    │    └─Dropout: 3-1171                                  --
# │    │    └─Dropout: 3-1172                                  --
# │    └─TransformerDecoderLayer: 2-135                        --
# │    │    └─MultiheadAttention: 3-1173                       16,785,408
# │    │    └─MultiheadAttention: 3-1174                       16,785,408
# │    │    └─Linear: 3-1175                                   16,785,408
# │    │    └─Dropout: 3-1176                                  --
# │    │    └─Linear: 3-1177                                   16,779,264
# │    │    └─LayerNorm: 3-1178                                4,096
# │    │    └─LayerNorm: 3-1179                                4,096
# │    │    └─LayerNorm: 3-1180                                4,096
# │    │    └─Dropout: 3-1181                                  --
# │    │    └─Dropout: 3-1182                                  --
# │    │    └─Dropout: 3-1183                                  --
# │    └─TransformerDecoderLayer: 2-136                        --
# │    │    └─MultiheadAttention: 3-1184                       16,785,408
# │    │    └─MultiheadAttention: 3-1185                       16,785,408
# │    │    └─Linear: 3-1186                                   16,785,408
# │    │    └─Dropout: 3-1187                                  --
# │    │    └─Linear: 3-1188                                   16,779,264
# │    │    └─LayerNorm: 3-1189                                4,096
# │    │    └─LayerNorm: 3-1190                                4,096
# │    │    └─LayerNorm: 3-1191                                4,096
# │    │    └─Dropout: 3-1192                                  --
# │    │    └─Dropout: 3-1193                                  --
# │    │    └─Dropout: 3-1194                                  --
# │    └─TransformerDecoderLayer: 2-137                        --
# │    │    └─MultiheadAttention: 3-1195                       16,785,408
# │    │    └─MultiheadAttention: 3-1196                       16,785,408
# │    │    └─Linear: 3-1197                                   16,785,408
# │    │    └─Dropout: 3-1198                                  --
# │    │    └─Linear: 3-1199                                   16,779,264
# │    │    └─LayerNorm: 3-1200                                4,096
# │    │    └─LayerNorm: 3-1201                                4,096
# │    │    └─LayerNorm: 3-1202                                4,096
# │    │    └─Dropout: 3-1203                                  --
# │    │    └─Dropout: 3-1204                                  --
# │    │    └─Dropout: 3-1205                                  --
# │    └─TransformerDecoderLayer: 2-138                        --
# │    │    └─MultiheadAttention: 3-1206                       16,785,408
# │    │    └─MultiheadAttention: 3-1207                       16,785,408
# │    │    └─Linear: 3-1208                                   16,785,408
# │    │    └─Dropout: 3-1209                                  --
# │    │    └─Linear: 3-1210                                   16,779,264
# │    │    └─LayerNorm: 3-1211                                4,096
# │    │    └─LayerNorm: 3-1212                                4,096
# │    │    └─LayerNorm: 3-1213                                4,096
# │    │    └─Dropout: 3-1214                                  --
# │    │    └─Dropout: 3-1215                                  --
# │    │    └─Dropout: 3-1216                                  --
# ├─Linear: 1-7                                                1,229,400,000
# ├─Softmax: 1-8                                               --
# =====================================================================================
# Total params: 11,224,713,408
# Trainable params: 11,224,713,408
# Non-trainable params: 0
# =====================================================================================
